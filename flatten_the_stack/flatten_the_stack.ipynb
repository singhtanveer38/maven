# %%
import pandas as pd
import json

# %%
df = pd.read_csv("sales_orders.csv", )
df.head()
# Out:
#    order_number  order_date  \
# 0        387005  2016-01-22
# 1        395005  2016-01-30
# 2        423011  2016-02-27
# 3        600006  2016-08-22
# 4        652002  2016-10-13
#
#                                           line_items fulfillment
# 0  [\r\n  {\r\n    "product": {\r\n      "product...    In store
# 1  [\r\n  {\r\n    "product": {\r\n      "product...    In store
# 2  [\r\n  {\r\n    "product": {\r\n      "product...    In store
# 3  [\r\n  {\r\n    "product": {\r\n      "product...      Online
# 4  [\r\n  {\r\n    "product": {\r\n      "product...    In store

# %%
df["line_items"][0]
# Out:
# '[\r\n  {\r\n    "product": {\r\n      "product_name": "MGS Age of Empires II Gold Edition2009 E172",\r\n      "product_price": 32\r\n    },\r\n    "quantity": 3\r\n  },\r\n  {\r\n    "product": {\r\n      "product_name": "A. Datum Bridge Digital Camera M300 Pink",\r\n      "product_price": 186.9\r\n    },\r\n    "quantity": 2\r\n  },\r\n  {\r\n    "product": {\r\n      "product_name": "WWI Desktop PC1.80 E1801 Silver",\r\n      "product_price": 269.9\r\n    },\r\n    "quantity": 1\r\n  }\r\n]'

# %%
df["line_items"] = df["line_items"].apply(json.loads)
df
# Out:
#     order_number  order_date  \
# 0         387005  2016-01-22
# 1         395005  2016-01-30
# 2         423011  2016-02-27
# 3         600006  2016-08-22
# 4         652002  2016-10-13
# ..           ...         ...
# 95       2144004  2020-11-13
# 96       2152009  2020-11-21
# 97       2165005  2020-12-04
# 98       2175000  2020-12-14
# 99       2192014  2020-12-31
#
#                                            line_items fulfillment
# 0   [{'product': {'product_name': 'MGS Age of Empi...    In store
# 1   [{'product': {'product_name': 'Contoso DVD 60 ...    In store
# 2   [{'product': {'product_name': 'Contoso 16GB Mp...    In store
# 3   [{'product': {'product_name': 'Contoso Water H...      Online
# 4   [{'product': {'product_name': 'Contoso Genuine...    In store
# ..                                                ...         ...
# 95  [{'product': {'product_name': 'Fabrikam Laptop...    In store
# 96  [{'product': {'product_name': 'Contoso Hybrid ...      Online
# ...

# %%
df = df.explode(column="line_items")
df
# Out:
#     order_number  order_date  \
# 0         387005  2016-01-22
# 0         387005  2016-01-22
# 0         387005  2016-01-22
# 1         395005  2016-01-30
# 1         395005  2016-01-30
# ..           ...         ...
# 98       2175000  2020-12-14
# 98       2175000  2020-12-14
# 98       2175000  2020-12-14
# 98       2175000  2020-12-14
# 99       2192014  2020-12-31
#
#                                            line_items fulfillment
# 0   {'product': {'product_name': 'MGS Age of Empir...    In store
# 0   {'product': {'product_name': 'A. Datum Bridge ...    In store
# 0   {'product': {'product_name': 'WWI Desktop PC1....    In store
# 1   {'product': {'product_name': 'Contoso DVD 60 D...    In store
# 1   {'product': {'product_name': 'SV DVD 38 DVD St...    In store
# ..                                                ...         ...
# 98  {'product': {'product_name': 'The Phone Compan...    In store
# 98  {'product': {'product_name': 'The Phone Compan...    In store
# ...

# %%
line_items = pd.json_normalize(df["line_items"])
line_items
# Out:
#      quantity                               product.product_name  \
# 0           3        MGS Age of Empires II Gold Edition2009 E172
# 1           2           A. Datum Bridge Digital Camera M300 Pink
# 2           1                    WWI Desktop PC1.80 E1801 Silver
# 3           5        Contoso DVD 60 DVD Storage Binder L20 Black
# 4           5            SV DVD 38 DVD Storage Binder E25 Silver
# ..        ...                                                ...
# 225         2  The Phone Company Smart phones without camera ...
# 226         4  The Phone Company PDA Phone Unlocked 3.7 inche...
# 227         3                   Fabrikam Laptop10.1 M0101 Silver
# 228         4          SV DVD 14-Inch Player Portable L100 White
# 229        10                     WWI Desktop PC1.80 E1801 Black
#
#      product.product_price
# 0                    32.00
# 1                   186.90
# 2                   269.90
# 3                    22.89
# 4                     9.99
# ...

# %%
orders = pd.concat([df.reset_index(), line_items], axis=1)
orders
# Out:
#      index  order_number  order_date  \
# 0        0        387005  2016-01-22
# 1        0        387005  2016-01-22
# 2        0        387005  2016-01-22
# 3        1        395005  2016-01-30
# 4        1        395005  2016-01-30
# ..     ...           ...         ...
# 225     98       2175000  2020-12-14
# 226     98       2175000  2020-12-14
# 227     98       2175000  2020-12-14
# 228     98       2175000  2020-12-14
# 229     99       2192014  2020-12-31
#
#                                             line_items fulfillment  quantity  \
# 0    {'product': {'product_name': 'MGS Age of Empir...    In store         3
# 1    {'product': {'product_name': 'A. Datum Bridge ...    In store         2
# 2    {'product': {'product_name': 'WWI Desktop PC1....    In store         1
# 3    {'product': {'product_name': 'Contoso DVD 60 D...    In store         5
# 4    {'product': {'product_name': 'SV DVD 38 DVD St...    In store         5
# ...

# %%
orders = orders.drop(labels=["index", "line_items"], axis=1)
orders
# Out:
#      order_number  order_date fulfillment  quantity  \
# 0          387005  2016-01-22    In store         3
# 1          387005  2016-01-22    In store         2
# 2          387005  2016-01-22    In store         1
# 3          395005  2016-01-30    In store         5
# 4          395005  2016-01-30    In store         5
# ..            ...         ...         ...       ...
# 225       2175000  2020-12-14    In store         2
# 226       2175000  2020-12-14    In store         4
# 227       2175000  2020-12-14    In store         3
# 228       2175000  2020-12-14    In store         4
# 229       2192014  2020-12-31    In store        10
#
#                                   product.product_name  product.product_price
# 0          MGS Age of Empires II Gold Edition2009 E172                  32.00
# 1             A. Datum Bridge Digital Camera M300 Pink                 186.90
# 2                      WWI Desktop PC1.80 E1801 Silver                 269.90
# ...

# %%
orders["product.product_name"] = orders["product.product_name"].str.replace(",", " ")

# %%
orders.to_csv("orders.csv", index=False)

# %%
orders["total_cost"] = orders["product.product_price"] * orders["quantity"]

# %%
orders["fulfillment"].value_counts()
# Out:
# fulfillment
# In store    194
# Online       36
# Name: count, dtype: int64

# %%
total_price = round(orders[orders["fulfillment"] == "Online"]["total_cost"].sum())

# %%
total_price
# Out:
# 18239
